# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
data_folder = Path('/Users/kristiinajoon/Desktop/4th_year/4th_year_project/Project/top_data/GEBCO_2019/')
file2open = data_folder / 'GEBCO_2019.nc' #file with location
nc_GEBCO = Dataset(file2open, 'r')
raw_lat = nc_GEBCO.variables['lat'][:] # import lat, in degrees N
raw_lon = nc_GEBCO.variables['lon'] # import lat, in degrees E 
raw_elevation = nc_GEBCO.variables['elevation'] # import lat, in m as height above reference ellipsoid

# Define domain
lat_Prt = raw_lat[30120:31536] #Indices for 35.5-41.4N obtained in MatLAB
lon_Prt = raw_lon[37920:39720] #Indices for -22 - -14.5E obtained in MatLAB
bathy_Prt = raw_elevation[30120:31536, 37920:39720]
# len_lat = len(lat_Prt)
len_lon = len(lon_Prt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
# ----> 1 data_folder = Path('/Users/kristiinajoon/Desktop/4th_year/4th_year_project/Project/top_data/GEBCO_2019/')
#       2 file2open = data_folder / 'GEBCO_2019.nc' #file with location
#       3 nc_GEBCO = Dataset(file2open, 'r')
#       4 raw_lat = nc_GEBCO.variables['lat'][:] # import lat, in degrees N
#       5 raw_lon = nc_GEBCO.variables['lon'] # import lat, in degrees E
#
# NameError: name 'Path' is not defined

# %%
import numpy as np
from math import pi, sin, cos, sqrt
from obspy.geodetics import gps2dist_azimuth
from pathlib import Path
from scipy.io import netcdf
from netCDF4 import Dataset

data_folder = Path('/Users/kristiinajoon/Desktop/4th_year/4th_year_project/Project/top_data/GEBCO_2019/')
file2open = data_folder / 'GEBCO_2019.nc' #file with location
nc_GEBCO = Dataset(file2open, 'r')
raw_lat = nc_GEBCO.variables['lat'][:] # import lat, in degrees N
raw_lon = nc_GEBCO.variables['lon'] # import lat, in degrees E 
raw_elevation = nc_GEBCO.variables['elevation'] # import lat, in m as height above reference ellipsoid

# Define domain
lat_Prt = raw_lat[30120:31536] #Indices for 35.5-41.4N obtained in MatLAB
lon_Prt = raw_lon[37920:39720] #Indices for -22 - -14.5E obtained in MatLAB
bathy_Prt = raw_elevation[30120:31536, 37920:39720]
# len_lat = len(lat_Prt)
len_lon = len(lon_Prt)

# %%
import numpy as np
from math import pi, sin, cos, sqrt
from obspy.geodetics import gps2dist_azimuth
from pathlib import Path
from scipy.io import netcdf
from netCDF4 import Dataset

def wgs84(): #WGSS84 coordinate system with Greenwich as lon = 0
    # set semi-major axis of the oblate spheroid Earth, in m
    a = 6378137.0
    # set semi-minor axis of the oblate spheroid Earth, in m
    b = 6356752.314245
    # calculate inverse flattening f
    f = a/(a-b)
    # calculate squared eccentricity e
    e_2 = (a**2-b**2)/a**2
    return(a,b,e_2,f)

def geograph_to_geocent(theta):
    # https://en.wikipedia.org/wiki/Latitude#Geocentric_latitude
    e_2 = wgs84()[2] # returns the 3rd item from function ouputs as start indexing from 0
    theta = np.rad2deg(np.arctan((1 - e_2) * np.tan(np.deg2rad(theta))))
    return theta

lat_Prt_cnt = geograph_to_geocent(lat_Prt)

# %%
lat = 40
r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
print(lat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 lat = 40
# ----> 2 r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
#       3 print(lat)
#
# NameError: name 'a' is not defined

# %%
lat = 40
a = wgs84()[0]
b = wgs84()[1]
r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
print(lat)
# Out:
# 40

# %%
def radius_cnt(lat):
    a = wgs84()[0]
    b = wgs84()[1]
    # Calculate radius for reference ellipsoid
    # in m 
    lat = pi/180*lat
    r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
    return(r_cnt)

# %%
suva=[20,25,30,35,40] 
suva_r = radius_cnt(suva)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
# ----> 2 suva_r = radius_cnt(suva)
#
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in radius_cnt(lat)
#       4     # Calculate radius for reference ellipsoid
#       5     # in m
# ----> 6     lat = pi/180*lat
#       7     r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
#       8     return(r_cnt)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
def radius_cnt(lat):
    a = wgs84()[0]
    b = wgs84()[1]
    # Calculate radius for reference ellipsoid
    # in m 
    lat = pi/180*lat
    for i in lat: 
        r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
    return(r_cnt)

# %%
suva=[20,25,30,35,40] 
suva_r = radius_cnt(suva)
print(suva_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
# ----> 2 suva_r = radius_cnt(suva)
#       3 print(suva_r)
#
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in radius_cnt(lat)
#       4     # Calculate radius for reference ellipsoid
#       5     # in m
# ----> 6     lat = pi/180*lat
#       7     for i in lat:
#       8         r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=[20,25,30,35,40] 
for i in suva
suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
#   File "<ipython-input-10-0745e9cf74e8>", line 2
#     for i in suva
#                  ^
# SyntaxError: invalid syntax

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva))
suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
#   File "<ipython-input-11-bc7665f248fd>", line 2
#     for i in range(len(suva))
#                              ^
# SyntaxError: invalid syntax

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva)):
suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
#   File "<ipython-input-12-afb79f407bd6>", line 3
#     suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
#          ^
# IndentationError: expected an indented block

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva)):
    suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
# [ 6360318.5164708   6377763.02177373  6357261.96639685  6374221.6941045
#   6366273.22850738]

# %%
suva=[20,25,30,35,40] 
suva = pi/180*suva
for i in range(len(suva)):
    suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
# ----> 2 suva = pi/180*suva
#       3 for i in range(len(suva)):
#       4     suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
#       5 print(suva_r)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva)):
    suva = pi/180*suva
    suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
#       2 for i in range(len(suva)):
# ----> 3     suva = pi/180*suva
#       4     suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
#       5 print(suva_r)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva)):
    suva_rad = pi/180*suva
    suva_r = np.sqrt((a**2*(np.cos(suva_rad)**2)) + (b**2*(np.sin(suva_rad)**2)))
print(suva_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
#       2 for i in range(len(suva)):
# ----> 3     suva_rad = pi/180*suva
#       4     suva_r = np.sqrt((a**2*(np.cos(suva_rad)**2)) + (b**2*(np.sin(suva_rad)**2)))
#       5 print(suva_r)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=[20,25,30,35,40] 
for i in range(len(suva)):
    suva_rad = pi/180*suva
print(suva_rad)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
#       2 for i in range(len(suva)):
# ----> 3     suva_rad = pi/180*suva
#       4 print(suva_rad)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=[20,25,30,35,40] 
suva_rad = pi/180*suva
print(suva_rad)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       1 suva=[20,25,30,35,40]
# ----> 2 suva_rad = pi/180*suva
#       3 print(suva_rad)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
suva=array([20,25,30,35,40])
suva_rad = pi/180*suva
print(suva_rad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
# ----> 1 suva=array([20,25,30,35,40])
#       2 suva_rad = pi/180*suva
#       3 print(suva_rad)
#
# NameError: name 'array' is not defined

# %%
suva=np.array([20,25,30,35,40])
suva_rad = pi/180*suva
print(suva_rad)
# Out:
# [ 0.34906585  0.43633231  0.52359878  0.61086524  0.6981317 ]

# %%
suva=np.array([20,25,30,35,40])
suva = pi/180*suva
suva_r = np.sqrt((a**2*(np.cos(suva)**2)) + (b**2*(np.sin(suva)**2)))
print(suva_r)
# Out:
# [ 6375639.17144682  6374322.8251149   6372797.55595936  6371109.57645456
#   6369310.06713248]

# %%
import numpy as np
from math import pi, sin, cos, sqrt
from obspy.geodetics import gps2dist_azimuth
from pathlib import Path
from scipy.io import netcdf
from netCDF4 import Dataset

# Reference surface will be the Earth as defined by the WGS84 ellipsoid
def radius_cnt(lat):
    a = wgs84()[0]
    b = wgs84()[1]
    # Calculate radius for reference ellipsoid
    # in m 
    lat = pi/180*lat
    # for i in range(len(lat)): 
    r_cnt = np.sqrt((a**2*(np.cos(lat)**2)) + (b**2*(np.sin(lat)**2)))
    return(r_cnt)

# suva = np.array([20,25,30,35,40])
# suva = pi/180*suva
# suva_r = radius_cnt(suva)
# print(suva_r)

#Calculate radius of reference surface at geocentric latitudes
r_cnt = radius_cnt(lat_Prt_cnt) 
r_cnt = array([r_cnt,]*len_lon)
# Calculate the radius for each bathymetry data point, in m 
r_cnt_bathy = r_cnt + bathy_Prt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#      24 #Calculate radius of reference surface at geocentric latitudes
#      25 r_cnt = radius_cnt(lat_Prt_cnt)
# ---> 26 r_cnt = array([r_cnt,]*len_lon)
#      27 # Calculate the radius for each bathymetry data point, in m
#      28 r_cnt_bathy = r_cnt + bathy_Prt
#
# NameError: name 'array' is not defined

# %%
print(r_cnt)
# Out:
# [6370997.063685107 6370995.600489102 6370994.137216836 ...,
#  6368868.062342312 6368866.5225373795 6368864.982700751]

# %%
#Calculate radius of reference surface at geocentric latitudes
r_cnt = radius_cnt(lat_Prt_cnt) 
r_cnt = np.array([r_cnt,]*len_lon)
# Calculate the radius for each bathymetry data point, in m 
r_cnt_bathy = r_cnt + bathy_Prt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Desktop/4th_year/4th_year_project/Project/top_data/geogr_geocentric.py in <module>
#       3 r_cnt = np.array([r_cnt,]*len_lon)
#       4 # Calculate the radius for each bathymetry data point, in m
# ----> 5 r_cnt_bathy = r_cnt + bathy_Prt
#
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/ma/core.py in __radd__(self, other)
#    4075         # In analogy with __rsub__ and __rdiv__, use original order:
#    4076         # we get here from `other + self`.
# -> 4077         return add(other, self)
#    4078
#    4079     def __sub__(self, other):
#
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/ma/core.py in __call__(self, a, b, *args, **kwargs)
#    1017         with np.errstate():
#    1018             np.seterr(divide='ignore', invalid='ignore')
# -> 1019             result = self.f(da, db, *args, **kwargs)
#    1020         # Get the mask for the result
#    1021         (ma, mb) = (getmask(a), getmask(b))
#
# ValueError: operands could not be broadcast together with shapes (1800,1416) (1416,1800)

# %%
r_cnt = np.array([r_cnt,]*len_lon).transpose()

# %%
#Calculate radius of reference surface at geocentric latitudes
r_cnt = radius_cnt(lat_Prt_cnt) 
r_cnt = np.array([r_cnt,]*len_lon).transpose()
# Calculate the radius for each bathymetry data point, in m 
r_cnt_bathy = r_cnt + bathy_Prt

# %%
print(r_cnt_bathy[0], r_cnt_bathy[-1])
# Out:
# [ 6365973.28243511  6365972.03829448  6365970.09688823 ...,
#   6366663.88888042  6366656.14766948  6366649.89669292] [ 6364820.56253474  6364838.07327692  6364851.06644099 ...,
#   6363518.80252497  6363511.8225445   6363514.70291559]

# %%
print(r_cnt_bathy[0,0], r_cnt_bathy[-1],-1)
# Out:
# 6365973.28244 [ 6364820.56253474  6364838.07327692  6364851.06644099 ...,
#   6363518.80252497  6363511.8225445   6363514.70291559] -1

# %%
print(r_cnt_bathy[0,0], r_cnt_bathy[-1, -1])
# Out:
# 6365973.28244 6363514.70292

# %%
print(r_cnt_bathy[0,0]-r_cnt_bathy[-1, -1])
# Out:
# 2458.57951951
